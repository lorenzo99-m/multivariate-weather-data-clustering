# %%
from mwdc import *

# %%
from mwdc.preprocessing import preprocessing
from mwdc.evaluation import st_evaluation
from mwdc.visualization import visualization

import pandas as pd

# %%
df = pd.read_csv('data/ERA5_meteo_sfc_2021_daily.csv')

# %%
df
# Out:
#      sp(43.0,-33.0)  sp(42.75,-33.0)  sp(42.5,-33.0)  sp(42.25,-33.0)  \
# 0          0.769017         0.763551        0.758399         0.754214
# 1          0.550508         0.539280        0.528615         0.520168
# 2          0.406872         0.391876        0.377439         0.365852
# 3          0.305465         0.282306        0.260121         0.241803
# 4          0.421539         0.398652        0.376436         0.357109
# ..              ...              ...             ...              ...
# 360        0.052561         0.047201        0.044078         0.046307
# 361        0.000000         0.000000        0.001187         0.007059
# 362        0.062689         0.061612        0.062288         0.067914
# 363        0.013697         0.005919        0.000000         0.000000
# 364        0.153705         0.148152        0.143691         0.143785
#
#      sp(42.0,-33.0)  sp(41.75,-33.0)  sp(41.5,-33.0)  sp(41.25,-33.0)  \
# ...

# %%
df.describe()
# Out:
#        sp(43.0,-33.0)  sp(42.75,-33.0)  sp(42.5,-33.0)  sp(42.25,-33.0)  \
# count      365.000000       365.000000      365.000000       365.000000
# mean         0.614472         0.612845        0.612030         0.613333
# std          0.199558         0.200340        0.200929         0.200565
# min          0.000000         0.000000        0.000000         0.000000
# 25%          0.496968         0.498679        0.496034         0.494562
# 50%          0.636403         0.636024        0.632559         0.634218
# 75%          0.769017         0.763551        0.765941         0.769881
# max          1.000000         1.000000        1.000000         1.000000
#
#        sp(42.0,-33.0)  sp(41.75,-33.0)  sp(41.5,-33.0)  sp(41.25,-33.0)  \
# count      365.000000       365.000000      365.000000       365.000000
# mean         0.614513         0.615771        0.617154         0.618673
# std          0.200359         0.200116        0.199884         0.199574
# ...

# %%
set([x.split('(')[0] for x in df.columns])
# Out:
# {'slhf', 'sp', 'sshf', 'sst', 't2m', 'u10', 'v10'}

# %%
len(set([x.split('(')[1] for x in df.columns])), len(df.columns)
# Out:
# (1681, 11767)

# %%
preprocessing.data_preprocessing('data/ERA5_meteo_sfc_2021_daily.csv', ['sp', 'sst', 'u10', 'v10', 'sshf', 'slhf', 't2m'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 preprocessing.data_preprocessing('data/ERA5_meteo_sfc_2021_daily.csv', ['sp', 'sst', 'u10', 'v10', 'sshf', 'slhf', 't2m'])
#
# File ~/Repositories/multivariate-weather-data-clustering/mwdc/preprocessing/preprocessing.py:300, in data_preprocessing(data_path, variables)
#     291 def data_preprocessing(data_path, variables):
#     292   ''' The parameters accepted by this function are as follows:
#     293     1. "data_path" is the path of the netCDF4 dataset file. (data_path = '/content/drive/MyDrive/ERA5_meteo_sfc_2021_daily.nc')
#     294     2. "variables" is an array of the variable names of the netCDF4 dataset those we want to read. (variables = ['sst', 'sp'])
#    (...)
# ...
